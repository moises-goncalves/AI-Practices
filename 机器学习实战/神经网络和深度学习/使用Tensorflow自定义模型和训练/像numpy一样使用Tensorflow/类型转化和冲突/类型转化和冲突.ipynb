# %% [markdown]
# # 将不同类型的张量进行操作会因为冲突而报错
# ## 整数加浮点树
# ## 不同精度的浮点数相加
# ## Tensorflow不会自动进行数据转化操作

# %%
import tensorflow as tf
tf.constant(2.) + tf.constant(50)
# Out:
# C:\Users\Administrator\anaconda3\envs\DeepLearning-py310\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[1], line 2
#       1 import tensorflow as tf
# ----> 2 tf.constant(2.) + tf.constant(50)
#
# File ~\anaconda3\envs\DeepLearning-py310\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# ...
