# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow_hub.keras_layer import keras

housing = fetch_california_housing()

X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target, random_state=42
)

X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, random_state=42
)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)
## 使用顺序API构建回归MLP
model = keras.Sequential()
model.add(keras.layers.Dense(30, activation="relu", input_shape=X_train.shape[1:]))
model.add(keras.layers.Dense(1))

model.compile(loss="mean_squared_error", optimizer="sgd")
checkpoint_cb = keras.callbacks.ModelCheckpoint("my_keras_model.h5")
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_valid, y_valid), callbacks=[checkpoint_cb])
# Out:
# C:\Users\Administrator\anaconda3\envs\DeepLearning-py310\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# Epoch 1/20
# 363/363 [==============================] - 2s 2ms/step - loss: 0.9175 - val_loss: 12.6529
# Epoch 2/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.5385 - val_loss: 3.0971
# Epoch 3/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4532 - val_loss: 0.3913
# Epoch 4/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4219 - val_loss: 0.4088
# Epoch 5/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4131 - val_loss: 0.4095
# Epoch 6/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4059 - val_loss: 0.4164
# Epoch 7/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4003 - val_loss: 0.4191
# Epoch 8/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3951 - val_loss: 0.4110
# Epoch 9/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3907 - val_loss: 0.4100
# Epoch 10/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3866 - val_loss: 0.4073
# Epoch 11/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3895 - val_loss: 0.4063
# Epoch 12/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3811 - val_loss: 0.3820
# Epoch 13/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3780 - val_loss: 0.3808
# Epoch 14/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3759 - val_loss: 0.3809
# Epoch 15/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3727 - val_loss: 0.3588
# Epoch 16/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3714 - val_loss: 0.3614
# Epoch 17/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3686 - val_loss: 0.3540
# Epoch 18/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3664 - val_loss: 0.3518
# Epoch 19/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3639 - val_loss: 0.5327
# Epoch 20/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3661 - val_loss: 0.7658

# %%
# 如果要在训练期间使用验证集 则可以在创建modelcheckpoint时设置save_best_only=True
checkpoint_cb = keras.callbacks.ModelCheckpoint("best_model.h5", save_best_only=True)
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_valid, y_valid), callbacks=[checkpoint_cb])
model = keras.models.load_model("best_model.h5")
# Out:
# Epoch 1/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3675 - val_loss: 0.4229
# Epoch 2/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3626 - val_loss: 0.3977
# Epoch 3/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3600 - val_loss: 0.3872
# Epoch 4/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3578 - val_loss: 0.4082
# Epoch 5/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3584 - val_loss: 0.3813
# Epoch 6/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3563 - val_loss: 0.3855
# Epoch 7/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3553 - val_loss: 0.3950
# Epoch 8/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3545 - val_loss: 0.3702
# Epoch 9/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3522 - val_loss: 0.3633
# Epoch 10/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3549 - val_loss: 0.3591
# Epoch 11/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3522 - val_loss: 0.3640
# Epoch 12/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3508 - val_loss: 0.4546
# Epoch 13/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3505 - val_loss: 0.4014
# Epoch 14/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3532 - val_loss: 0.3760
# Epoch 15/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3490 - val_loss: 0.3702
# Epoch 16/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3472 - val_loss: 0.3706
# Epoch 17/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3477 - val_loss: 0.4030
# Epoch 18/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3482 - val_loss: 0.3735
# Epoch 19/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3470 - val_loss: 0.3411
# Epoch 20/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3440 - val_loss: 0.3845
