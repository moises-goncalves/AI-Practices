# %%
import os
root_logdir = os.path.join(os.curdir, "my_logs")

def get_run_logdir():
    import time
    run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
    return os.path.join(root_logdir, run_id)

run_logdir = get_run_logdir()
print("Writing to logdir: %s" % run_logdir)
# Out:
# Writing to logdir: .\my_logs\run_2025_10_23-20_54_35

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow_hub.keras_layer import keras

housing = fetch_california_housing()

X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target, random_state=42
)

X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, random_state=42
)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)
## 使用顺序API构建回归MLP
model = keras.Sequential()
model.add(keras.layers.Dense(30, activation="relu", input_shape=X_train.shape[1:]))
model.add(keras.layers.Dense(1))

model.compile(loss="mean_squared_error", optimizer="sgd")

# %%
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_valid, y_valid), callbacks=[tensorboard_cb])
# Out:
# Epoch 1/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.8528 - val_loss: 0.5610
# Epoch 2/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.5155 - val_loss: 89.2714
# Epoch 3/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.7724 - val_loss: 8.7587
# Epoch 4/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4387 - val_loss: 12.2484
# Epoch 5/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.5001 - val_loss: 28.6999
# Epoch 6/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.5393 - val_loss: 2.5168
# Epoch 7/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4211 - val_loss: 0.4195
# Epoch 8/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3894 - val_loss: 0.3565
# Epoch 9/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3823 - val_loss: 0.3766
# Epoch 10/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3774 - val_loss: 0.3930
# Epoch 11/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3738 - val_loss: 0.4034
# Epoch 12/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3717 - val_loss: 0.3912
# Epoch 13/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3695 - val_loss: 0.4015
# Epoch 14/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3653 - val_loss: 0.4060
# Epoch 15/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3683 - val_loss: 0.3985
# Epoch 16/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3631 - val_loss: 0.3711
# Epoch 17/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3611 - val_loss: 0.3526
# Epoch 18/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3564 - val_loss: 0.3660
# Epoch 19/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3544 - val_loss: 0.3650
# Epoch 20/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3526 - val_loss: 0.3693
